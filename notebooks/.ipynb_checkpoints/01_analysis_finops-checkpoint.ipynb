# %% [markdown]
# # Analysis finops

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
cost_by_user = pd.read_csv("/home/tatiane/repositorios/finops-data-cost-monitoring/data/analysis/cost_by_user.csv")
anomalies = pd.read_csv("/home/tatiane/repositorios/finops-data-cost-monitoring/data/analysis/anomalies.csv")

cost_by_user.head()
# Out:
#    user_id  total_cost
# 0       33   543.65260
# 1      192   489.14950
# 2      163   438.48395
# 3      102   426.59715
# 4      108   418.17060

# %%
# Usuários mais caros
top_users = cost_by_user.sort_values(by='total_cost', ascending=False).head(10)
top_users
# Out:
#    user_id  total_cost
# 0       33  543.652600
# 1      192  489.149500
# 2      163  438.483950
# 3      102  426.597150
# 4      108  418.170600
# 5      197  410.498075
# 6      172  403.541500
# 7      115  398.889900
# 8      131  397.891350
# 9      183  386.710600

# %%
# Visualização
plt.figure()
top_users.set_index('user_id')['total_cost'].plot(kind='bar')

plt.title("Top 10 usuários mais caros")
plt.xlabel("User ID")
plt.ylabel("Custo total")

plt.xticks(rotation=45)
plt.show()

# %%
# Distribuição de custos
plt.figure()
cost_by_user['total_cost'].hist()

plt.title("Distribuição de custo por usuário")
plt.xlabel("Custo")
plt.ylabel("Frequência")

plt.show()

# %%
# Análise de anomalias
anomalies.head()
# Out:
#    user_id  job_id  compute_hours  storage_gb  queries_run        date  \
# 0      104  job_49          21.70      589.32         1060  2026-01-03
# 1      186  job_49          19.63      479.45          938  2026-01-03
# 2       86  job_16          35.98      123.30         1276  2026-01-04
# 3      183  job_36          34.07      715.20          922  2026-01-04
# 4      115   job_7          12.07      733.62         1804  2026-01-07
#
#   cloud_provider     region profile   job_type  ... usage_intensity  \
# 0            aws  us-east-1    high  streaming  ...            high
# 1            aws  us-west-2    high  streaming  ...            high
# 2          azure  sa-east-1    high  streaming  ...            high
# 3          azure  us-east-1    high     ad-hoc  ...            high
# 4            aws  sa-east-1    high     ad-hoc  ...            high
#
#    compute_cost  storage_cost  query_cost  region_mult  instance_mult  \
# ...

# %%
# Visualizar magnitude
plt.figure()
anomalies['total_cost'].hist()

plt.title("Distribuição de custos anômalos")
plt.show()

# %%
# Principais anomalias
top_anomalies = anomalies.sort_values(by='total_cost', ascending=False).head(10)
top_anomalies
# Out:
#     user_id  job_id  compute_hours  storage_gb  queries_run        date  \
# 10      163  job_23          99.31      561.75         1776  2026-01-15
# 37      114  job_34          60.29      718.96          650  2026-02-13
# 28      160  job_16          54.27      559.48         1012  2026-02-05
# 48      188  job_20          63.56      380.59         1624  2026-03-01
# 55       33  job_13          36.68      737.79         1480  2026-03-10
# 38      131   job_7          45.27      624.45          422  2026-02-15
# 36      192  job_47          34.42      678.43         1920  2026-02-12
# 57      108  job_33          35.09      714.42          582  2026-03-12
# 2        86  job_16          35.98      123.30         1276  2026-01-04
# 19       33  job_19          37.93       11.29          798  2026-01-20
#
#    cloud_provider     region profile   job_type  ... usage_intensity  \
# 10          azure  us-west-2    high      batch  ...            high
# ...

# %%
# Comparação geral vs anomalias
plt.figure()

plt.hist(cost_by_user['total_cost'], alpha=0.5, label='Normal')
plt.hist(anomalies['total_cost'], alpha=0.7, label='Anomalias')

plt.legend()
plt.title("Distribuição: Normal vs Anomalias")

plt.show()

# %%
# Percentual dos top 10
top_10_cost = top_users['total_cost'].sum()
total_cost = cost_by_user['total_cost'].sum()

print(f"Top 10 representam {100 * top_10_cost / total_cost:.2f}% do custo total")
# Out:
# Top 10 representam 11.30% do custo total
